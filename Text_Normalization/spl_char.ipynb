# %%
with open('data.txt','r') as file:
    data =  file.read()
    for char in data:
        if not char.isalnum() and not ord(char) == 32:
            data = data.replace(char,'')
            # print(data)
print(data)
# Out:
# python is a high level object oriented dynamically typed interpreted scripting language as well as programming language
