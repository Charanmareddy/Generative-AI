# %% [markdown]
# pip install emoji

# %%
import emoji

# %%
s = 'Hellooooooo ✌️😒😎😃'
emoji.replace_emoji(s,"")
# Out:
# 'Hellooooooo '

# %%
s = 'Hellooooooo ✌️😒😎😃💙💚❤️🤜🫰😏🤬🤗'
emoji.demojize(s)
# Out:
# 'Hellooooooo :victory_hand::unamused_face::smiling_face_with_sunglasses::grinning_face_with_big_eyes::blue_heart::green_heart::red_heart::right-facing_fist::hand_with_index_finger_and_thumb_crossed::smirking_face::face_with_symbols_on_mouth::smiling_face_with_open_hands:'
