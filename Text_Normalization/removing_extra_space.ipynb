# %%
with open('data.txt','r+') as file:
    data = file.read()
    words = data.split()
    data = ' '.join(words)
    file.seek(0)
    file.write(data)

# %%
print(data)
# Out:
# python is a high level object oriented dynamically typed interpreted scripting language as well as programming language readable and simple python emphasizes code readability and uses indentation whitespace to structure blocks of code rather than brackets which many other languages use interpreted and dynamic it is an interpreted language meaning code is executed linebyline this allows developers to quickly spot errors and test software variables are also dynamically typed so you dont need to specify their data type when writing the code massive ecosystem python features an extensive batteriesincluded standard library and is supported by a massive ecosystem of thirdparty frameworks and librariespython is a high level object oriented dynamically typed interpreted scripting language as well as programming language readable and simple python emphasizes code readability and uses indentation whitespace to structure blocks of code rather than brackets which many other languages use interpr
# ...
