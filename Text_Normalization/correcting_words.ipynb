# %%
from textblob import TextBlob

# %%
text = "corrting the wods for txt normaliztion"
text1 = 'corret the wods for txt normalization'
corrected_words = TextBlob(text1).correct() # If we dont use correct() method simply it will store the text in the textblob object like <class 'textblob.blob.TextBlob'>
print(corrected_words, type(corrected_words))
# Out:
# correct the words for txt normalization <class 'textblob.blob.TextBlob'>

# %% [markdown]
# - it will not correct the complete 100% of words it will just correct only few words around 70% of words
